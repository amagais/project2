# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

import numpy as np

# Study data files
USA_metadata = "data/food_environment_data.csv"

# %%
# Read the data
USA_metadata = pd.read_csv(USA_metadata)
USA_metadata
# Out:
#    Unnamed: 0  2009 WIC Participants  2011 WIC Participants  \
# 0          AK                25816.0                26295.0
# 1          AL               140810.0               143768.0
# 2          AR                94107.0                93461.0
# 3          AZ               208873.0               199343.0
# 4          CA              1439006.0              1466564.0
# 5          CO               107930.0               104129.0
# 6          CT                60148.0                56083.0
# 7          DC                17473.0                16537.0
# 8          DE                24028.0                22553.0
# 9          FL               505671.0               492071.0
# 10         GA               499213.0               469456.0
# 11         HI                36320.0                36753.0
# 12         IA                75645.0                70931.0
# 13         ID                46175.0                44020.0
# 14         IL               309870.0               295409.0
# ...

# %%
USA_metadata.columns
# Out:
# Index(['Unnamed: 0', '2009 WIC Participants', '2011 WIC Participants',
#        '2012 WIC Participants', '2013 WIC Participants',
#        '2014 WIC Participants', '2015 WIC Participants',
#        '2009 National Lunch School Program Participants',
#        '2011 National Lunch School Program Participants',
#        '2012 National Lunch School Program Participants',
#        ...
#        'Full-service Restaurants 2014',
#        '%Chg Full-service Restaurants 2009 to 2014',
#        'Full-service Restaurants 2009 per 1,000/pop',
#        'Full-service Restaurants 2014 per 1,000/pop',
#        '%Chg Household Food Insecurity 2010 to 2012',
#        '%Chg Household Food Insecurity 2013 to 2015',
#        '%Chg Household Food Insecurity 2010-12 to 2013-15',
#        '%Chg Household Very Low Food Insecurity 2010 to 2012',
#        '%Chg Household Very Low Food Insecurity 2013 to 2015',
#        '%Chg Household Very Low Food Insecurity 2010-12 to 2013-15'],
# ...
